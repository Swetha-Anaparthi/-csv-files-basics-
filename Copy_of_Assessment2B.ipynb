# %% [markdown]
# <a href="https://colab.research.google.com/github/Swetha-Anaparthi/-csv-files-basics-/blob/main/Copy_of_Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
file1=pd.read_csv(r"/content/college_1.csv")
file1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
file2=pd.read_csv(r"/content/college_2.csv")
file2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
output=pd.merge(file1,file2,how="outer")
output
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:1208: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
very_high=output.loc[output["CodeKata Score"]>=15000]
very_high.to_csv(r"Exceeded expectations.csv")

# %%
high=output.loc[(output["CodeKata Score"]<15000) &(output["CodeKata Score"]>=10000)]
high.to_csv(r"Reached expectations.csv")

# %%
med=output.loc[(output["CodeKata Score"]<10000) &(output["CodeKata Score"]>=7000)]
med.to_csv(r"Needs Improvement.csv")

# %%
low=output.loc[(output["CodeKata Score"]<7000)]
low.to_csv(r"Unsatisfactory.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
prev_ck=output["Previous Geekions"].sum()
prev_ck
# Out:
# 457240

# %%
pre_ck=output["CodeKata Score"].sum()
pre_ck
# Out:
# 482160

# %%
avg_ck=(prev_ck+pre_ck)/2
avg_ck
# Out:
# 469700.0

# %%
pre_ck_mean=(output["CodeKata Score"]).mean()
pre_ck_mean
# Out:
# 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
output.shape
# Out:
# (119, 9)

# %%
a,b=output.shape
a
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
py_cou_mean=(output["python"]).mean()
py_cou_mean
# Out:
# 54.35294117647059

# %%
my_sql_mean=(output["mysql"]).mean()
my_sql_mean
# Out:
# 23.5

# %%
py_en_mean=(output["python_en"]).mean()
py_en_mean
# Out:
# 29.65714285714286

# %%
comp_think_mean=(output["computational_thinking"]).mean()
comp_think_mean
# Out:
# 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_star=output.sort_values(by="Rising",ascending=False)
rising_star.head(3)
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 102        Computer Science and Engineering    2000       -1.0
# 86         Computer Science and Engineering    2000       55.0
#
#      computational_thinking
# 92                      0.0
# 102                     0.0
# 86                      6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
shining_star=output.sort_values(by="Previous Geekions",ascending=False)
shining_star.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
sums=output.groupby(output["Department"])["CodeKata Score"].sum()
sums
# Out:
# Department
# Computer Science and Engineering             320025
# Electronics and Communication Engineering    108335
# Electronics and Electrical Engineering        53800
# Name: CodeKata Score, dtype: int64

# %%
plt.pie(sums,labels=sums.index,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
eee=output.loc[output["Department"]=="Electronics and Electrical Engineering"].sort_values(by="CodeKata Score",ascending=False)
eee_top=eee.head(3)
eee_top
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
# 88      VIINU V P    -1.0   24.0               9150            9150
# 92       shifak N    58.0    0.0               5180            8320
#
#                                 Department  Rising  python_en  \
# 84  Electronics and Electrical Engineering       0        0.0
# 88  Electronics and Electrical Engineering       0      100.0
# 92  Electronics and Electrical Engineering    3140        0.0
#
#     computational_thinking
# 84                     9.0
# 88                    -1.0
# 92                     0.0

# %%
ece=output.loc[output["Department"]=="Electronics and Communication Engineering"].sort_values(by="CodeKata Score",ascending=False)
ece_top=ece.head(3)
ece_top
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 87  Bodipudi Harini    -1.0   35.0              10040           10040
# 91        Gowtham R    -1.0    4.0               8650            8650
# 6     KALAIARASAN K    85.0   47.0               7750            7880
#
#                                    Department  Rising  python_en  \
# 87  Electronics and Communication Engineering       0        0.0
# 91  Electronics and Communication Engineering       0       60.0
# 6   Electronics and Communication Engineering     130        NaN
#
#     computational_thinking
# 87                    -1.0
# 91                     6.0
# 6                      NaN

# %%
cse=output.loc[output["Department"]=="Computer Science and Engineering"].sort_values(by="CodeKata Score",ascending=False)
cse_top=cse.head(3)
cse_top
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.bar(x=cse_top["Name"],height=cse_top["CodeKata Score"])
plt.title("CSE TOPPERS")
plt.subplot(1,3,2)
plt.bar(x=ece_top["Name"],height=ece_top["CodeKata Score"],color="g")
plt.title("ECE TOPPERS")
plt.subplot(1,3,3)
plt.bar(x=eee_top["Name"],height=eee_top["CodeKata Score"],color="r")
plt.title("EEE TOPPERS")
# Out:
# Text(0.5, 1.0, 'EEE TOPPERS')
